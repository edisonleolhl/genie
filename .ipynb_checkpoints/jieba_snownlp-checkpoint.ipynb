# %%
filename = "jianshu.txt"
with open(filename, "r+", encoding='utf-8') as f:
    mytext = f.read()

# %%
mytext
# Out:
# '你一定没见过好中文的样子\n96  王佩  Signed 关注\n2017.11.07 09:47* 字数 3326 阅读 8726评论 33喜欢 260赞赏 1\n 750*560-写作课.jpg\n750*560-写作课.jpg\n常有人问，写作为什么这么难？\n\n写作之所以难，是因为语言是线性的，而人的思维则是网状的。\n\n写作要把网状的思维，按照语法理成树状，再变成一串字符写出来。这好比从一团棉花中，纺出一根线，再织成一件美丽的衣服。任何一个环节出错，都会使最终结果难遂人愿。\n\n王佩老师的“好中文写作班”，已经开办到第二期，他可以帮你破解写作之难。因为他掌握了砸开坚硬的写作之壳的两个重要方法：输入和输出。\n\n输入为了输出\n\n很多人平常读书也罢，观影看剧也罢，往往抱着娱乐心态，或者漫无目的。王佩老师的“好中文写作班”认为，要想破解写作之难，提高写作水平，就要从输入这个源头抓起。牢牢树立“输入是为了输出”的观念。\n\n输入为了输出，首先要看输入什么\n\n软件工程上有一句俗语叫“Garbage in, garbage out”，垃圾进，垃圾出。为了提高输出质量，输入质量也必须提高。王佩老师，会带你到好中文的源头，从中国古典的文言文，到自古以来的传统白话文；从古代佛经的翻译、圣经的翻译，直到建国后马列著作的翻译；从鲁迅、张爱玲、老舍到阿城；从诗歌到戏剧；从小说到网游台词。凡有井水处，必有好中文。\n\n输入为了输出，要掌握“和合技”\n\n和合技（全称：和合本创作技巧，简称TUV），是百年前西方传教士在翻译和合本《圣经》的过程中积累总结出的一套流程。它与现代程序员喜欢的Github的工作原理，惊人地吻合。在“好中文写作班”第一期中，大家用Github的方式，还原了百年前传教士所使用的和合本翻译方法。\n\n利用这种方法，可以集思广益，共同鉴赏，共同创作。辅以小组制（每组不超过5个人）学习机制，这种方法更能如虎添翼。仅仅学习了“和合技”，就足以值回票价。\n\n输入为了输出，还要掌握“故事力”\n\n故事力是王佩老师在“好中文写作课”上提出的一个重要概念，在广泛研究了故事的实质、材料、结构以及风格以后，采取“降维攻击”的办法，王佩老师总结出了数十种常用的“故事力”。掌握这些“故事力”，不但能让你讲出好故事，创作出好作品，涉足非虚构创作、小说创作和编剧领域，而且能让你的学习和工作，提高到一个崭新的维度。\n\n输出的核心是心智、文采\n\n王佩老师作为史蒂芬·平克《风格感觉--21世纪写作指南》的中文译者之一，对于平克开创的认知写作学了然于心，但又不甚满意。因为平克的写作理论以英语为中心，而连一窥美丽汉语堂奥的机会都没有。王佩老师就把自己的心得、反思，结合汉语输入输出的实践，批判性地改进了这套理论，提出了心智写作的概念。\n\n心智写作的基础是古典文体\n\n古典文体是向古今中外古典作家学习借鉴的一种文体，它是治疗当代文章各种累赘、啰嗦、叠床架屋坏文风的一剂良药。\n\n古典文体的信条是：清晰简单如最真。它是一种格调，真理在握，娓娓道来。一句是一句，句句有来历，句句之间讲逻辑。\n\n古典文体就是打开一扇窗户，带读者去观看。而作者自己隐身，不絮絮叨叨谈自己。\n\n比如法国作家让.德.拉布吕埃这句：\n\n“人一辈子只做三件事：出生、生活和死亡。人无法感受出生的喜悦，只能饱受死亡的煎熬，忘记了生活。”\n古典文体的关键就是对语言特别自信，相信没有语言表达不出来的思想，只要是受过教育的人，我就能让他看懂，无论多么高深的科技和道理。\n\n这好比，你带朋友到海边游泳，你对这块地形和潮汐都有研究，你知道3点钟，潮水从西边上来了。你对朋友说：\n\n“现在是三点，看西边，潮水上来了。”而不是滔滔不绝地告诉他，怎么研究出来的这个结果。你的朋友朝西边一看，也点头赞许你。\n\n古典文体又好比一个家庭主妇，请了客人到家里，到了点，端上刚烤的香喷喷的糕点。\n\n如果带着客人去厨房，看满地的面团，狼藉的现场，滚滚浓烟，就不是古典文体。\n\n总之，古典文体就是做到八个字：清晰简单，优雅得体。\n\n心智写作必须有修辞意识\n\n仅仅古典文体，还不能算好文章，好文章必须有文采，文采离不开修辞。\n\n但修辞不是油嘴滑舌，而是修辞立其诚。写文章要诚意满满，不可虚情假意，猫哭耗子。幽默有时是必要的，单不要为了抖机灵而抖机灵，不要嬉皮笑脸，一点正经没有。\n\n文有伪真。伪善之文，行之不远，至诚文字，传之千古。\n\n司马迁因言致祸，惨受腐刑，如果不写文章为自己辩护，千古奇耻，岂不白受了。此时，恰有好友任安来信，劝他建言进贤，一句话触动了太史公的伤痛。他写了封回信，这就是千古传颂的《报任安书》。他回信之时，任安已经因事下狱，等待秋后问斩。而司马迁把一腔热血，满腹赤诚，化成文字，对这位即将离世的朋友，道出了自己的苦难与坚守。\n同样地，李清照身经离乱，在丈夫赵明诚去世，丈夫一生所收藏的金石字画被劫被偷被焚之后，写下了《金石录后序》，成为千古痛文。如果仅有修辞，而不立其诚，不会如此感人。\n心智写作就是自由地上下抽象阶梯\n\n对讲故事的人来说，抽象阶梯是最好用的工具之一，尽管它并不容易理解。哪怕是美国资深记者和作家，也得花了大概15年以上才能得心应手地运用它。\n\n抽象阶梯理论认为，所有语言都位于阶梯上。最概括或抽象的语言和概念在阶梯的顶端，而最具体、最明确的话语则在阶梯的底部。\n\n在讲故事时，我们在阶梯顶端创造意义，而在底部去做例证。\n\n比如，你要刻画一个朴实的农民形象，如果只说他“乐观向上、淳朴善良”，你还处于抽象阶梯的顶部。这个时候，你要来到抽象阶梯的底部来说话。\n\n你可以让这个农民说：\n\n“我是一个农民。我们农民都是乐观的。因为只要有点收成，就比撒下的种子多。”\n王佩老师可以让你用半年时间掌握美国记者15年才能掌握的抽象阶梯技巧，让你的写作从此如庖丁解牛，游刃有余。\n\n好中文写作使你成为一个更好的人\n\n乔治-奥威尔说：\n\n“我写作就因为我有一些热切的话，急切想找个人听。我知道一些谎言，不得不揭穿。我发现一些事实，必须马上警醒世人。但如果没有找到符合审美的方式，我不肯写一篇专栏，更枉论一本书。”\n王佩认为：\n\n“好中文写作”的宗旨是离好中文近一些，再近一些，让心智焕发出光彩，让输出与输入相配。整个旅程耗时半年，24讲堂课，不少于48次的交流，6本一起读的图书，10万字的写书计划，以及说不尽聊不完的文字。半年之后你可以验证，自己是不是已经变得更好了一些。\n反正王佩老师说，他自己变得更好了。\n\n.jpg\n.jpg\n本次课程分为三大部分：选修、必修、福利\n\n.jpg\n.jpg\n必修\n\n-好中文随堂24讲，每周一次，每次1.5-2h，单节课相当于普通课程的三倍\n-带读好中文，内含6本精选图书，每月一本\n\n好中文24讲分为六大板块：\n好中文的源头\n好中文和合技\n讲故事的人\n经典文风\n修辞感觉\n心智文采\n\n.jpg\n.jpg\n选修\n\n-本期课程将发起10万字写书计划的活动，附以打卡设置，鼓励学员在半年时间里，起码完成十万字的输出。\n-京沪杭三地线下活动，王佩老师认为一切的相遇都是为了最终面对面的交流。\n\n.jpg\n.jpg\n福利\n\n-在10万字写书计划中表现优秀、突出者，将有机会推荐出版或签约\n-王佩老师将拟邀好朋友采铜、卫西谛做客好中文课程\n-学员将在课程结束之前收到王佩版简书包，内含两本推荐图书\n-好中文优秀学员徽章发送\n什么是好中文学员徽章，有什么用，且听简叔道来~给拥有简书徽章的作者的几句话\n\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n.jpg\n饱醉豚说：\n\n“王佩每天熬夜读书。他随身带小红本，背诵很多唐诗宋词。他也大段大段地背诵莎士比亚剧本的台词。\n大多数人一辈子读书的数量，不如王佩在3年时间内读过的书多。\n大多人凭一辈子的努力，也做不到杭州日报的高级编辑。\n大多数人一辈子的努力，也做不出《新西湖》这个档次的杂志。”\n刘淼说：\n\n我和王佩有许多共同爱好，读书写作等等。我记得有一阵子我们都有想法，想要进军英文写作领域，于是不亦乐乎地交流起来，还彼此用英文写过一些信。到后来我们都意识到，母语才是我们的武器，这个是命中注定的，改不了。于是王佩又转回到中文的研究上，还写了“好中文的样子”等一系列的文章。\n十多年前，王佩就出了一本叫作《正版语文》的书，由他在新京报上的专栏文章结集而成。这些年，他又转向编剧工作，有作品在北京人民艺术剧院上演，也有作品到台湾演出。\n.jpg\n.jpg\n.jpg\n.jpg\n微信群+专业工具\n\n.jpg\n.jpg\n.jpg\n.jpg\n\n限时特价680，请在页面内领取优惠券~\n\n.jpg\n.jpg\n开课时间：2017年11月24日，为期半年，国家法定假日休息，课程时间会顺延\n好中文24讲时间：每周五晚20：00-22：00\n主题交流及作业选评：每周一、三（特殊情况会改在周二或周四，国定假日暂停）的下午17：00-18：00\n每月第一个周六20:00-22:00，会带读一本书。\n\n.gif\n.gif\n购买本课，将是你2017年最正确的选择之一，也将领跑你的2018个人成长计划。\n\n报名方式：\n\n方式一：搜索关注公众号简书大学堂（jianshuit），后台回复“好中文”即可获得报名链接\n\ ...

# %%
import jieba

# %%
mytext_div = " ".join(jieba.cut(mytext))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lhl\AppData\Local\Temp\jieba.cache
# Loading model cost 0.773 seconds.
# Prefix dict has been built succesfully.

# %%
print(mytext_div)
# Out:
# 你 一定 没见 过 好 中文 的 样子
#  96     王佩     Signed   关注
#  2017.11 . 07   09 : 47 *   字数   3326   阅读   8726 评论   33 喜欢   260 赞赏   1
#    750 * 560 - 写作 课 . jpg
#  750 * 560 - 写作 课 . jpg
#  常有 人问 ， 写作 为什么 这么 难 ？
#
#  写作 之所以 难 ， 是因为 语言 是 线性 的 ， 而 人 的 思维 则 是 网状 的 。
#
#  写作 要 把 网状 的 思维 ， 按照 语法 理 成 树状 ， 再 变成 一串 字符 写 出来 。 这 好比 从 一团 棉花 中 ， 纺出 一根 线 ， 再 织成 一件 美丽 的 衣服 。 任何 一个 环节 出错 ， 都 会 使 最终 结果 难 遂 人愿 。
#
#  王佩 老师 的 “ 好 中文 写作班 ” ， 已经 开办 到 第二期 ， 他 可以 帮 你 破解 写作 之难 。 因为 他 掌握 了 砸开 坚硬 的 写作 之壳 的 两个 重要 方法 ： 输入 和 输出 。
#
#  输入 为了 输出
#
#  很多 人 平常 读书 也罢 ， 观影 看剧 也罢 ， 往往 抱 着 娱乐 心态 ， 或者 漫无目的 。 王佩 老师 的 “ 好 中文 写作班 ” 认为 ， 要 想 破解 写作 之难 ， 提高 写作水平 ， 就要 从 输入 这个 源头 抓起 。 牢牢 树立 “ 输入 是 为了 输出 ” 的 观念 。
#
#  输入 为了 输出 ， 首先 要 看 输入 什么
#
#  软件工程 上 有 一句 俗语 叫 “ Garbage   in ,   garbage   out ” ， 垃圾 进 ， 垃圾 出 。 为了 提高 输出 质量 ， 输入 质量 也 必须 提高 。 王佩 老师 ， 会带 你 到 好 中文 的 源头 ， 从 中国 古典 的 文言文 ， 到 自古以来 的 传统 白话文 ； 从 古代 佛经 的 翻译 、 圣经 的 翻译 ， 直到 建国 后 马列著作 的 翻译 ； 从 鲁迅 、 张爱玲 、 老舍 到 阿城 ； 从 诗歌 到 戏剧 ； 从 小说 到 网游 台词 。 凡有 井水 处 ， 必有 好 中文 。
#
#  输入 为了 输出 ， 要 掌握 “ 和 合技 ”
#
#  和 合技 （ 全称 ： 和 合本 创作技巧 ， 简称 TUV ） ， 是 百年 前 西方 传教士 在 翻译 和 合本 《 圣经 》 的 过程 中 积累 总结 出 的 一套 流程 。 它 与 现代 程序员 喜欢 的 Github 的 工作 原理 ， 惊人 地 吻合 。 在 “ 好 中文 写作班 ” 第一期 中 ， 大家 用 Github 的 方式 ， 还原 了 百年 前 传教士 所 使用 的 和 合本 翻译 方法 。
#
#  利用 这种 方法 ， 可以 集思广益 ， 共同 鉴赏 ， 共同 创作 。 辅以 小组 制 （ 每组 不 超过 5 个人 ） 学习 机制 ， 这种 方法 更能 如虎添翼 。 仅仅 学习 了 “ 和 合技 ” ， 就 足以 值回 票价 。
#
#  输入 为了 输出 ， 还要 掌握 “ 故事 力 ”
#
#  故事 力是 王佩 老师 在 “ 好 中文 写作 课 ” 上 提出 的 一个 重要 概念 ， 在 广泛 研究 了 故事 的 实质 、 材料 、 结构 以及 风格 以后 ， 采取 “ 降维 攻击 ” 的 办法 ， 王佩 老师 总结 出 了 数十种 常用 的 “ 故事 力 ” 。 掌握 这些 “ 故事 力 ” ， 不但 能 让 你 讲 出 好 故事 ， 创作 出 好 作品 ， 涉足 非 虚构 创作 、 小说 创作 和 编剧 领域 ， 而且 能 让 你 的 学习 和 工作 ， 提高 到 一个 崭新 的 维度 。
#
#  输出 的 核心 是 心智 、 文采
#
#  王佩 老师 作为 史蒂芬 · 平克 《 风格 感觉 - - 21 世纪 写作 指南 》 的 中文 译者 之一 ， 对于 平克 开创 的 认知 写作学 了然于心 ， 但 又 不 甚 满意 。 因为 平克 的 写作 理论 以 英语 为 中心 ， 而 连 一 窥 美丽 汉语 堂奥 的 机会 都 没有 。 王佩 老师 就 把 自己 的 心得 、 反思 ， 结合 汉语 输入输出 的 实践 ， 批判性 地 改进 了 这套 理论 ， 提出 了 心智 写作 的 概念 。
#
#  心智 写作 的 基础 是 古典 文体
#
#  古典 文体 是 向 古今中外 古典 作家 学习 借鉴 的 一种 文体 ， 它 是 治疗 当代 文章 各种 累赘 、 啰嗦 、 叠床架屋 坏 文风 的 一剂 良药 。
#
#  古典 文体 的 信条 是 ： 清晰 简单 如 最 真 。 它 是 一种 格调 ， 真理 在握 ， 娓娓道来 。 一句 是 一句 ， 句句 有 来历 ， 句句 之间 讲 逻辑 。
#
#  古典 文体 就是 打开 一扇 窗户 ， 带 读者 去 观看 。 而 作者 自己 隐身 ， 不 絮絮叨叨 谈 自己 。
#
#  比如 法国 作家 让 . 德 . 拉布 吕埃 这句 ：
#
#  “ 人 一辈子 只 做 三件 事 ： 出生 、 生活 和 死亡 。 人 无法 感受 出生 的 喜悦 ， 只能 饱受 死亡 的 煎熬 ， 忘记 了 生活 。 ”
#  古典 文体 的 关键 就是 对 语言 特别 自信 ， 相信 没有 语言表达 不 出来 的 思想 ， 只要 是 受过 教育 的 人 ， 我 就 能 让 他 看 懂 ， 无论 多么 高深 的 科技 和 道理 。
#
#  这 好比 ， 你 带 朋友 到 海边 游泳 ， 你 对 这块 地形 和 潮汐 都 有 研究 ， 你 知道 3 点钟 ， 潮水 从 西边 上来 了 。 你 对 朋友 说 ：
#
#  “ 现在 是 三点 ， 看 西边 ， 潮水 上来 了 。 ” 而 不是 滔滔不绝 地 告诉 他 ， 怎么 研究 出来 的 这个 结果 。 你 的 朋友 朝西边 一看 ， 也 点头 赞许 你 。
#
#  古典 文体 又 好比 一个 家庭主妇 ， 请 了 客人 到 家里 ， 到 了 点 ， 端上 刚 烤 的 香喷喷 的 糕点 。
#
#  如果 带 着 客人 去 厨房 ， 看 满地 的 面团 ， 狼藉 的 现场 ， 滚滚 浓烟 ， 就 不是 古典 文体 。
#
#  总之 ， 古典 文体 就是 做到 八个 字 ： 清晰 简单 ， 优雅 得体 。
#
#  心智 写作 必须 有 修辞 意识
#
#  仅仅 古典 文体 ， 还 不能 算好 文章 ， 好 文章 必须 有 文采 ， 文采 离不开 修辞 。
#
#  但 修辞 不是 油嘴滑舌 ， 而是 修辞 立其诚 。 写文章 要 诚意 满满 ， 不可 虚情假意 ， 猫哭耗子 。 幽默 有时 是 必要 的 ， 单 不要 为了 抖 机灵 而 抖 机灵 ， 不要 嬉皮笑脸 ， 一点 正经 没有 。
#
#  文有 伪真 。 伪善 之文 ， 行之不远 ， 至诚 文字 ， 传之 千古 。
#
#  司马迁 因言致 祸 ， 惨受 腐刑 ， 如果 不 写文章 为 自己 辩护 ， 千古 奇耻 ， 岂 不白受 了 。 此时 ， 恰有 好友 任安 来信 ， 劝 他 建言 进贤 ， 一句 话 触动 了 太史公 的 伤痛 。 他 写 了 封 回信 ， 这 就是 千古 传颂 的 《 报 任安 书 》 。 他 回信 之 时 ， 任安 已经 因 事 下狱 ， 等待 秋后 问斩 。 而 司马迁 把 一腔热血 ， 满腹 赤诚 ， 化成 文字 ， 对 这位 即将 离世 的 朋友 ， 道 出 了 自己 的 苦难 与 坚守 。
#  同样 地 ， 李清照 身 经 离乱 ， 在 丈夫 赵明诚 去世 ， 丈夫 一生 所 收藏 的 金石 字画 被劫 被 偷 被 焚 之后 ， 写下 了 《 金石 录 后序 》 ， 成为 千古 痛文 。 如果 仅 有 修辞 ， 而 不立 其诚 ， 不会 如此 感人 。
#  心智 写作 就是 自由 地上 下 抽象 阶梯
#
#  对 讲故事 的 人 来说 ， 抽象 阶梯 是 最好 用 的 工具 之一 ， 尽管 它 并 不 容易 理解 。 哪怕 是 美国 资深 记者 和 作家 ， 也 得 花 了 大概 15 年 以上 才能 得心应手 地 运用 它 。
#
#  抽象 阶梯 理论 认为 ， 所有 语言 都 位于 阶梯 上 。 最 概括 或 抽象 的 语言 和 概念 在 阶梯 的 顶端 ， 而 最 具体 、 最 明确 的 话语 则 在 阶梯 的 底部 。
#
#  在 讲故事 时 ， 我们 在 阶梯 顶端 创造 意义 ， 而 在 底部 去 做 例证 。
#
#  比如 ， 你 要 刻画 一个 朴实 的 农民 形象 ， 如果 只 说 他 “ 乐观 向上 、 淳朴 善良 ” ， 你 还 处于 抽象 阶梯 的 顶部 。 这个 时候 ， 你 要 来到 抽象 阶梯 的 底部 来 说话 。
#
#  你 可以 让 这个 农民 说 ：
#
#  “ 我 是 一个 农民 。 我们 农民 都 是 乐观 的 。 因为 只要 有点 收成 ， 就 比撒下 的 种子 多 。 ”
#  王佩 老师 可以 让 你 用 半年 时间 掌握 美国 记者 15 年 才能 掌握 的 抽象 阶梯 技巧 ， 让 你 的 写作 从此 如 庖丁解牛 ， 游刃有余 。
#
#  好 中文 写作 使 你 成为 一个 更好 的 人
#
#  乔治 - 奥威尔 说 ：
#
#  “ 我 写作 就 因为 我 有 一些 热切 的话 ， 急切 想 找 个人 听 。 我 知道 一些 谎言 ， 不得不 揭穿 。 我 发现 一些 事实 ， 必须 马上 警醒 世人 。 但 如果 没有 找到 符合 审美 的 方式 ， 我 不肯 写 一篇 专栏 ， 更枉论 一 本书 。 ”
#  王佩 认为 ：
#
#  “ 好 中文 写作 ” 的 宗旨 是 离 好 中文 近 一些 ， 再近 一些 ， 让 心智 焕发 出 光彩 ， 让 输出 与 输入 相配 。 整个 旅程 耗时 半年 ， 24 讲堂 课 ， 不少 于 48 次 的 交流 ， 6 本 一起 读 的 图书 ， 10 万字 的 写 书 计划 ， 以及 说 不尽 聊 不 完 的 文字 。 半年 之后 你 可以 验证 ， 自己 是不是 已经 变得 更好 了 一些 。
#  反正 王佩 老师 说 ， 他 自己 变得 更好 了 。
#
#  . jpg
#  . jpg
#  本次 课程 分为 三 大部分 ： 选修 、 必修 、 福利
#
#  . jpg
#  . jpg
#  必修
#
#  - 好 中文 随堂 24 讲 ， 每周 一次 ， 每次 1.5 - 2h ， 单节 课 相当于 普通 课程 的 三倍
#  - 带读 好 中文 ， 内含 6 本 精选 图书 ， 每月 一本
#
#  好 中文 24 讲 分为 六大 板块 ：
#  好 中文 的 源头
#  好 中文 和 合技
#  讲故事 的 人
#  经典 文风
#  修辞 感觉
#  心智 文采
#
#  . jpg
#  . jpg
#  选修
#
#  - 本期 课程 将 发起 10 万字 写 书 计划 的 活动 ， 附以 打卡 设置 ， 鼓励 学员 在 半年 时间 里 ， 起码 完成 十万 字 的 输出 。
#  - 京沪 杭三地 线下 活动 ， 王佩 老师 认为 一切 的 相遇 都 是 为了 最终 面对面 的 交流 。
#
#  . jpg
#  . jpg
#  福利
#
#  - 在 10 万字 写 书 计划 中 表现 优秀 、 突出者 ， 将 有 机会 推荐 出版 或 签约
#  - 王佩 老师 将 拟 邀好 朋友 采铜 、 卫西谛 做客 好 中文 课程
#  - 学员 将 在 课程 结束 之前 收到 王佩版 简 书包 ， 内含 两本 推荐 图书
#  - 好 中文 优秀 学员 徽章 发送
#  什么 是 好 中文 学员 徽章 ， 有 什么 用 ， 且 听 简叔道 来 ~ 给 拥有 简书 徽章 的 作者 的 几句话
#
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  饱醉豚 说 ：
#
#  “ 王佩 每天 熬夜 读书 。 他 随身带 小红本 ， 背诵 很多 唐诗宋词 。 他 也 大段 大段 地 背诵 莎士比亚 剧本 的 台词 。
#  大多数 人 一辈子 读书 的 数量 ， 不如 王佩 在 3 年 时间 内读 过 的 书 多 。
#  大多 人 凭 一辈子 的 努力 ， 也 做 不到 杭州 日报 的 高级 编辑 。
#  大多数 人 一辈子 的 努力 ， 也 做 不出 《 新 西湖 》 这个 档次 的 杂志 。 ”
#  刘淼 说 ：
#
#  我 和 王佩有 许多 共同爱好 ， 读书 写作 等等 。 我 记得 有 一阵子 我们 都 有 想法 ， 想要 进军 英文 写作 领域 ， 于是 不亦乐乎 地 交流 起来 ， 还 彼此 用 英文 写过 一些 信 。 到 后来 我们 都 意识 到 ， 母语 才 是 我们 的 武器 ， 这个 是 命中注定 的 ， 改不了 。 于是 王佩 又 转 回到 中文 的 研究 上 ， 还 写 了 “ 好 中文 的 样子 ” 等 一系列 的 文章 。
#  十多年 前 ， 王佩 就 出 了 一本 叫作 《 正版 语文 》 的 书 ， 由 他 在 新 京报 上 的 专栏 文章 结集 而成 。 这些 年 ， 他 又 转向 编剧 工作 ， 有 作品 在 北京人民艺术剧院 上演 ， 也 有 作品 到 台湾 演出 。
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#  微信群 + 专业 工具
#
#  . jpg
#  . jpg
#  . jpg
#  . jpg
#
#  限时 特价 680 ， 请 在 页面 内 领取 优惠券 ~
#
#  . jpg
#  . jpg
#  开课时间 ： 2017 年 11 月 24 日 ， 为期 半年 ， 国家 法定 假日 休息 ， 课程 时间 会 顺延
#  好 中文 24 讲 时间 ： 每周五 晚 20 ： 00 - 22 ： 00
#  主题 交流 及 作业 选评 ： 每周 一 、 三 （ 特殊 情况 会改 在 周二 或 周四 ， 国定假日 暂停 ） 的 下午 17 ： 00 - 18 ： 00
#  每月 第一个 周六 20 : 00 - 22 : 00 ， 会带 读 一 本书 。
#
#  . gif
#  . gif
#  购买 本课 ， 将 是 你 2017 年 最 正确 的 选择 之一 ， 也 将领 跑 你 的 2018 个人成长 计划 。
#
#  报名 方式 ：
#
#  方式 一 ： 搜索 关注 公众 号 简书 大学堂 （ jianshuit ） ， 后台 回复 “ 好 中文 ” 即可 获得 报名 链接
#
#  方式 二 ： 直接 添加 班长 微信 bingbing938752
#
#    好 中文 的 样子   ©   著作权 归 作者 所有   举报 文章
#  96   关注 王佩     Signed
#  写 了   410476   字 ， 被   31727   人 关注 ， 获得 了   15075   个 喜欢
#  十分 精力 ： 四分 读书 ， 三分 写书 ， 三分 教书 。 《 正版 语文 》 作者 ， 21 世纪 最牛 写作 书   《 风格 感觉 》 （ The   Sense   of   Style ） 中文 译者 之一 ， “ 好 中文 的 样子 ” 创办人 和 主讲人 。
#  赞赏 的 方式 有 很多 ， 这 一种 最 简单 、 直接 。

# %%
from textblob import TextBlob
text = "I am happy today. I feel sad today."
from textblob import TextBlob
blob = TextBlob(text)
blob

# %%
blob.sentences

# %%
# !python -m textblob.download_corpora
